# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ###### Plotting from pandas DataFrames

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price']= car_sales['Price'].str.replace('[\$\,\. ]', '')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# remove last two zeroes
car_sales['Price'] = car_sales['Price'].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Sale Date'] = pd.date_range('1/1/2020', periods = len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
type(car_sales['Price'])
# Out:
# pandas.core.series.Series

# %%
car_sales['Total Sales']= car_sales['Price'].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
## plot the total sales
car_sales.plot(x = 'Sale Date', y= 'Total Sales');

# %%
car_sales['Price']= car_sales['Price'].astype(int)
car_sales.plot(x= 'Odometer (KM)', y= 'Price', kind='scatter');

# %%
car_sales.plot(x = 'Odometer (KM)', y = 'Price', kind = 'bar');

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.08214444, 0.92228012, 0.9370965 , 0.96467851],
#        [0.1686014 , 0.81239417, 0.72345608, 0.42260751],
#        [0.18628897, 0.1969814 , 0.36045621, 0.67047329],
#        [0.41021309, 0.31150753, 0.71493867, 0.85138048],
#        [0.58686956, 0.43812836, 0.44353908, 0.2196958 ],
#        [0.9550009 , 0.58546278, 0.96872632, 0.24324211],
#        [0.67030123, 0.4556983 , 0.46204577, 0.48132597],
#        [0.62720754, 0.10491605, 0.65858657, 0.02523647],
#        [0.19309213, 0.42553262, 0.36714543, 0.68907132],
#        [0.82378721, 0.26839949, 0.48669065, 0.36053079]])

# %%
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.082144  0.922280  0.937097  0.964679
# 1  0.168601  0.812394  0.723456  0.422608
# 2  0.186289  0.196981  0.360456  0.670473
# 3  0.410213  0.311508  0.714939  0.851380
# 4  0.586870  0.438128  0.443539  0.219696
# 5  0.955001  0.585463  0.968726  0.243242
# 6  0.670301  0.455698  0.462046  0.481326
# 7  0.627208  0.104916  0.658587  0.025236
# 8  0.193092  0.425533  0.367145  0.689071
# 9  0.823787  0.268399  0.486691  0.360531

# %%
df.plot.bar();

# %%
df.plot(kind = 'bar');

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x='Make', y = 'Odometer (KM)', kind = 'bar');

# %%
car_sales['Odometer (KM)'].plot.hist();

# %%
car_sales['Odometer (KM)'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales['Odometer (KM)'].plot.hist(bins = 10);

# %%
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease['age'].plot.hist();

# %%
heart_disease['age'].plot.hist(bins=50);

# %%
heart_disease['age'].plot.hist();

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(subplots = True, figsize = (10,30));

# %% [markdown]
# ### Which plot to use:
#
# * When plotting something quickly, okay to use the pyplot method
# * When plotting something more advanced, use OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease ['age'] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over_50)
# Out:
# 208

# %%
over_50.plot(kind = 'scatter', x= 'age', y = 'chol', c = 'target');

# %%
## OO Method
fix, ax = plt.subplots(figsize = (10,6))
over_50.plot(kind = 'scatter', x = 'age',y = 'chol', c = 'target',ax = ax);

# %%
### OO method from scratch
fig, ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50['age'],
                    y= over_50['chol'],
                    c= over_50['target'])
ax.set(title = 'Heary Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol');
ax.legend(*scatter.legend_elements(), title = 'target');

# %%
fig, ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50['age'],
                    y= over_50['chol'],
                    c= over_50['target'])
ax.set(title = 'Heary Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol');
ax.legend(*scatter.legend_elements(), title = 'target');
ax.axhline(over_50['chol'].mean(), linestyle = '--');

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplot of chol, age,  thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols = 1, figsize = (10, 10))
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c= over_50['target'])

ax0.set(title = 'Heart Disease and Cholestrol Levels', xlabel = 'age', ylabel = 'Cholestrol')
ax0.legend(*scatter.legend_elements(), title = 'Target')
ax0.axhline(y = over_50['chol'].mean(), linestyle = '--');

scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c= over_50['target'])

ax1.set(title = 'Heart Disease and Max Heart Rate', xlabel = 'age', ylabel = 'thalach')
ax1.legend(*scatter.legend_elements(), title = 'Target')
ax1.axhline(y = over_50['thalach'].mean(), linestyle = '--');

# %%
# subplot of chol, age,  thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols = 1, figsize = (10, 10))
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c= over_50['target'])

ax0.set(title = 'Heart Disease and Cholestrol Levels', xlabel = 'age', ylabel = 'Cholestrol')
ax0.legend(*scatter.legend_elements(), title = 'Target')
ax0.axhline(y = over_50['chol'].mean(), linestyle = '--');

scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c= over_50['target'])

ax1.set(title = 'Heart Disease and Max Heart Rate', xlabel = 'age', ylabel = 'thalach')
ax1.legend(*scatter.legend_elements(), title = 'Target')
ax1.axhline(y = over_50['thalach'].mean(), linestyle = '--');
fig.suptitle('Heart Diesease Analysis', fontsize =16, fontweight = 'bold' );

# %% [markdown]
# ##### Custmizing Matplotlib plots and getting stylish

# %%
# See different styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('tableau-colorblind10');

# %%
car_sales['Price'].plot();

# %%
plt.style.use('ggplot');
car_sales['Price'].plot();

# %%
x= np.random.randn(10,4)
x
# Out:
# array([[ 1.73797348e+00, -6.45612604e-01,  1.52648584e+00,
#          4.38118462e-01],
#        [-2.44168754e-01, -4.25862739e-01, -5.41101663e-01,
#          2.00681662e+00],
#        [ 1.25499049e+00, -6.11165132e-01, -1.17067985e+00,
#         -2.03704590e-03],
#        [-2.31557913e-01, -8.57899131e-01, -9.90273704e-01,
#         -1.79323337e+00],
#        [ 6.58948726e-01, -8.17850736e-01,  6.03732879e-02,
#         -5.90590684e-01],
#        [-4.38532370e-01,  6.83021442e-01,  2.28288712e+00,
#          8.09544981e-01],
#        [-3.24764898e-01,  9.48457736e-01,  7.47411647e-02,
#          2.89421128e-01],
#        [ 6.55948774e-01,  4.96760633e-01,  5.22134600e-01,
#          2.72177670e-01],
#        [-1.62900312e+00, -1.43650605e+00,  4.88224028e-01,
#         -8.44378834e-03],
#        [-1.08153183e+00,  1.53803038e+00,  9.45335927e-01,
#          6.70841413e-01]])

# %%
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  1.737973 -0.645613  1.526486  0.438118
# 1 -0.244169 -0.425863 -0.541102  2.006817
# 2  1.254990 -0.611165 -1.170680 -0.002037
# 3 -0.231558 -0.857899 -0.990274 -1.793233
# 4  0.658949 -0.817851  0.060373 -0.590591
# 5 -0.438532  0.683021  2.282887  0.809545
# 6 -0.324765  0.948458  0.074741  0.289421
# 7  0.655949  0.496761  0.522135  0.272178
# 8 -1.629003 -1.436506  0.488224 -0.008444
# 9 -1.081532  1.538030  0.945336  0.670841

# %%
ax = df.plot(kind= 'bar')

# %%
ax = df.plot(kind = 'bar')
ax.set(title = 'Random Number Bar Graph from DataFrame', xlabel = 'Row Number', ylabel = 'Random Number')
ax.legend().set_visible(True)

# %%
##Set the Style
plt.style.use('seaborn-whitegrid')

### OO method from scratch
fig, ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50['age'],
                    y= over_50['chol'],
                    c= over_50['target'],
                    cmap = 'winter') # This change is color scheme
ax.set(title = 'Heary Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol');
ax.legend(*scatter.legend_elements(), title = 'target');
ax.axhline(over_50['chol'].mean(), linestyle = '--');

# %%
##Set the Style
plt.style.use('seaborn-whitegrid')

### OO method from scratch
fig, ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50['age'],
                    y= over_50['chol'],
                    c= over_50['target'],
                    cmap = 'summer') # This change is color scheme
ax.set(title = 'Heary Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol');
ax.legend(*scatter.legend_elements(), title = 'target');
ax.axhline(over_50['chol'].mean(), linestyle = '--');

# %%
##Set the Style
plt.style.use('seaborn-whitegrid')

### OO method from scratch
fig, ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50['age'],
                    y= over_50['chol'],
                    c= over_50['target'],
                    cmap = 'plasma') # This change is color scheme
ax.set(title = 'Heary Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol');
ax.legend(*scatter.legend_elements(), title = 'target');
ax.axhline(over_50['chol'].mean(), linestyle = '--');

# %%
##Set the Style
plt.style.use('seaborn-whitegrid')

### OO method from scratch
fig, ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50['age'],
                    y= over_50['chol'],
                    c= over_50['target'],
                    cmap = 'winter') # This change is color scheme
ax.set(title = 'Heary Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol');
ax.legend(*scatter.legend_elements(), title = 'target');
ax.axhline(over_50['chol'].mean(), linestyle = '--');

# %%
##Set the Style
plt.style.use('seaborn-whitegrid')

# subplot of chol, age,  thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols = 1, figsize = (10, 10))
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c= over_50['target'], cmap= 'winter')

ax0.set(title = 'Heart Disease and Cholestrol Levels', xlabel = 'age', ylabel = 'Cholestrol')
ax0.legend(*scatter.legend_elements(), title = 'Target')
ax0.axhline(y = over_50['chol'].mean(), linestyle = '--');

scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c= over_50['target'], cmap = 'winter')

ax1.set(title = 'Heart Disease and Max Heart Rate', xlabel = 'age', ylabel = 'thalach')
ax1.legend(*scatter.legend_elements(), title = 'Target')
ax1.axhline(y = over_50['thalach'].mean(), linestyle = '--');
fig.suptitle('Heart Diesease Analysis', fontsize =16, fontweight = 'bold' );

# %%
# subplot of chol, age,  thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols = 1, figsize = (10, 10))
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c= over_50['target'], cmap= 'winter')

ax0.set(title = 'Heart Disease and Cholestrol Levels', xlabel = 'age', ylabel = 'Cholestrol')
ax0.legend(*scatter.legend_elements(), title = 'Target')
ax0.axhline(y = over_50['chol'].mean(), linestyle = '--');
ax0.set_xlim([50,80])
scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c= over_50['target'],  cmap= 'winter')

ax1.set(title = 'Heart Disease and Max Heart Rate', xlabel = 'age', ylabel = 'thalach')
ax1.legend(*scatter.legend_elements(), title = 'Target')
ax1.axhline(y = over_50['thalach'].mean(), linestyle = '--');
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])


fig.suptitle('Heart Diesease Analysis', fontsize =16, fontweight = 'bold' );
